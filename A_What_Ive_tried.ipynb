# %% [markdown]
# # This is a list of what I've tried and the performance metrics of the test-set.

# %% [markdown]
# Baseline:
# r2-score: 0.6786
# Quantile loss: 3590964.1258

# %% [markdown]
# Updated Baseline with xgb train() instead of fit() since objective function choice did not work.
# r2-score: 0.6931
# Quantile loss: 4784342.3608

# %% [markdown]
# Custom objective function:
# r2-score: 0.0000
# Quantile loss: 4157323.3123

# %% [markdown]
# Built in objective function: I think these don't work since we are predicting single receivals, which we are unlikely to hit on the correct date.
# r2-score: 0.0000
# Quantile loss: 4157323.3123

# %% [markdown]
# Baseline:
# r2-score: 0.6786
# Quantile loss: 3590964.1258
# Flat scaling: 0.8
# r2-score: 0.4945
# Quantile loss: 2628591.4462
# Flat scaling: 0.6
# r2-score: -0.1365
# Quantile loss: 2479119.9808
# Flat scalin: 0.4
# r2-score: -2.6133
# Quantile loss: 2550067.5073
# Flat Scaling:  0.5
# r2-score: -0.9328
# Quantile loss: 2425083.9578

# %% [markdown]
# Linear scaling:  0  to  1
# r2-score: 0.3655
# Quantile loss: 2538266.8513
# Linear scaling:  0.0  to  0.5
# r2-score: -3.0470
# Quantile loss: 2813240.1713
# Linear scaling:  0.0  to  0.7
# r2-score: -0.6307
# Quantile loss: 2421094.2146

# %% [markdown]
# Curved scaling:  0.0  to  0.7  with factor:  1.0 #Same as before
# r2-score: -0.6307
# Quantile loss: 2421094.2146
# Curved scaling:  0.0  to  1.0  with factor:  2
# r2-score: -0.1102
# Quantile loss: 2439926.4437
# Curved scaling:  0  to  1  with factor:  2.5
# r2-score: -0.3822
# Quantile loss: 2420339.7812

# %% [markdown]
# Baseline: Model with longer rolling_averages and lag_feature
# r2-score: 0.6691
# Quantile loss: 4122526.1058

# %% [markdown]
# Bounded predictions < 5 to 0.
# r2-score: 0.6732
# Quantile loss: 4137227.8354

# %% [markdown]
# TODO:
# Curved scaling based on frequency/certainity.
# More rolling averages
# Static rolling averages (not recursively updated)
#
# Cumulative weight prediction with quantile error "baked in"
